# %%
import nbformat

# Replace with the path to your broken notebook
input_path = r"C:\Users\Menaka\Downloads\wikipedia_chatbot.ipynb"
output_path = r"C:\Users\Menaka\Downloads\wikipedia_chatbot.ipynb"

# Read notebook
nb = nbformat.read(input_path, as_version=4)

# Remove widgets metadata if present
if "widgets" in nb.get("metadata", {}):
    del nb["metadata"]["widgets"]

# Save the cleaned notebook
nbformat.write(nb, output_path)
print(f"✅ Cleaned notebook saved to: {output_path}")
# Out:
# ✅ Cleaned notebook saved to: C:\Users\Menaka\Downloads\wikipedia_chatbot.ipynb
